# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK (unknown) token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3081, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels 

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'as', 'term', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        # note that the highest score is the word itself
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.020905
# Nearest to world: american, des, jack, hoboken, milk, superb, octave, sympathizer,
# Nearest to united: headline, standoff, dada, mandolin, brimstone, macrobiotic, chaired, brightly,
# Nearest to to: quipped, albatrosses, teaspoon, leonhard, mucous, jewell, gels, cappella,
# Nearest to more: shops, berne, platonic, rush, pads, ground, endowment, liberalism,
# Nearest to no: subsidised, removes, cautioned, poking, neely, ordinal, plutonic, flint,
# Nearest to would: van, unsophisticated, electricity, longed, cio, hollowed, morse, verbose,
# Nearest to in: sequencer, tahiti, achieved, mixers, hermeneutics, refuse, hugo, embarked,
# Nearest to years: lesbos, barren, buson, keralites, confusing, intrigue, qh, indulgence,
# Nearest to had: attract, zawahiri, conformation, nmt, hoffman, secundus, thucydides, utilize,
# Nearest to state: messenger, mmm, druyan, infocom, hub, appendage, besieging, lui,
# Nearest to there: resumption, addresses, pave, writable, sightseeing, mermaid, burgundy, armouries,
# Nearest to nine: crowley, rectified, digraph, aar, plating, elkhart, shouts, ezln,
# Nearest to th: chambers, cartier, catastrophic, ok, scrupulously, slowing, escalated, massacre,
# Nearest to zero: pt, frey, kurtosis, gregorio, eminem, playground, galante, calwell,
# Nearest to their: resisted, proposals, er, mayhem, ccf, plectrum, rivalled, stromata,
# Nearest to which: detoxification, beasts, settlers, indictment, slough, bactria, mouths, loosening,
# Average loss at step 2000: 4.444521
# Average loss at step 4000: 3.875602
# Average loss at step 6000: 3.488736
# Average loss at step 8000: 3.737399
# Average loss at step 10000: 3.675547
# Nearest to world: american, hitch, milk, superb, eubulides, juli, hoboken, sintering,
# Nearest to united: headline, mandolin, brimstone, dada, caribs, foldoc, standoff, brightly,
# Nearest to to: bottlenose, quipped, from, satisfiable, admirer, psalms, stressed, uris,
# Nearest to more: yew, bunny, rather, shops, falciparum, straining, sukkot, evolution,
# Nearest to no: woensel, hannity, aw, removes, largo, taiping, jadwiga, braille,
# Nearest to would: can, may, cio, will, beat, van, ingress, tomorrow,
# Nearest to in: at, of, and, bundesland, old, jb, following, javier,
# Nearest to years: barren, lesbos, year, firestone, boeotia, keralites, intrigue, heat,
# Nearest to had: attract, has, have, was, minogue, mcclory, confederal, were,
# Nearest to state: hub, knot, messenger, singhasari, powerless, eugenics, zombies, tdi,
# Nearest to there: they, it, resumption, refund, now, edomites, smooth, clover,
# Nearest to nine: eight, six, seven, five, three, four, zero, two,
# Nearest to th: pressurised, scrupulously, fear, ok, catastrophic, chambers, putney, polyester,
# Nearest to zero: eight, five, three, four, six, nine, two, seven,
# Nearest to their: its, his, parr, any, the, electromechanical, record, resisted,
# Nearest to which: that, this, it, also, hafez, who, uncircumcised, darwinian,
# Average loss at step 12000: 3.613695
# Average loss at step 14000: 3.632571
# Average loss at step 16000: 3.569546
# Average loss at step 18000: 3.556499
# Average loss at step 20000: 3.469960
# Nearest to world: american, hitch, koan, practice, banister, civil, hartmann, death,
# Nearest to united: headline, brimstone, caribs, foldoc, mandolin, homelands, standoff, brightly,
# Nearest to to: will, and, dozenal, opcode, would, cannot, for, through,
# Nearest to more: less, most, yew, very, falciparum, straining, cavalrymen, rather,
# Nearest to no: this, which, absinthium, ergot, landmass, aw, taiping, removes,
# Nearest to would: can, will, may, could, should, might, must, newsgroup,
# Nearest to in: during, on, at, with, jb, within, from, as,
# Nearest to years: year, barren, lesbos, days, boeotia, stresemann, grounding, firestone,
# Nearest to had: has, have, was, were, been, attract, oeis, as,
# Nearest to state: tdi, zombies, oxidising, messenger, hub, scoop, defects, bernie,
# Nearest to there: they, it, he, neurotoxicity, often, which, still, smooth,
# Nearest to nine: seven, eight, six, five, four, zero, three, one,
# Nearest to th: scrupulously, tartarus, warms, pressurised, eoka, fear, ok, polyester,
# Nearest to zero: five, seven, four, six, three, eight, nine, two,
# Nearest to their: his, its, the, some, any, managua, her, dart,
# Nearest to which: this, that, also, it, who, untouchables, and, no,
# Average loss at step 22000: 3.533519
# Average loss at step 24000: 3.546477
# Average loss at step 26000: 3.573714
# Average loss at step 28000: 3.546696
# Average loss at step 30000: 3.492478
# Nearest to world: practice, name, death, hartmann, cold, hitch, eugenic, parenting,
# Nearest to united: headline, caribs, brimstone, foldoc, homelands, personification, mandolin, fai,
# Nearest to to: through, for, can, against, cannot, dozenal, supplier, in,
# Nearest to more: less, most, very, straining, yew, demonstrating, mostly, chocolat,
# Nearest to no: any, too, a, this, fully, dimensional, jadwiga, there,
# Nearest to would: can, will, may, might, could, must, should, cannot,
# Nearest to in: during, jb, prematurely, since, on, with, until, at,
# Nearest to years: days, year, lesbos, caria, firestone, equalizer, barren, stresemann,
# Nearest to had: has, have, was, were, oeis, after, cores, yet,
# Nearest to state: government, zombies, tdi, zimmermann, attainment, hub, messenger, office,
# Nearest to there: they, it, he, often, now, still, this, which,
# Nearest to nine: eight, seven, six, five, zero, four, three, two,
# Nearest to th: scrupulously, eoka, tartarus, pressurised, zero, nine, seven, polyester,
# Nearest to zero: five, seven, eight, nine, four, six, three, two,
# Nearest to their: its, his, the, her, them, any, electromechanical, some,
# Nearest to which: that, this, who, also, but, however, there, often,
# Average loss at step 32000: 3.487643
# Average loss at step 34000: 3.492166
# Average loss at step 36000: 3.411593
# Average loss at step 38000: 3.462064
# Average loss at step 40000: 3.435767
# Nearest to world: civil, cold, eugenic, vowel, largest, spitzer, season, name,
# Nearest to united: headline, caribs, brimstone, homelands, foldoc, fai, personification, storyline,
# Nearest to to: opcode, cannot, benevento, satisfiable, can, gladiatorial, disappearing, would,
# Nearest to more: less, most, very, phonetically, straining, rather, alonso, larger,
# Nearest to no: any, lethe, landmass, too, dimensional, calcio, delusion, nothing,
# Nearest to would: will, can, may, could, might, should, must, cannot,
# Nearest to in: during, prematurely, until, at, on, within, jb, from,
# Nearest to years: days, year, caria, times, decades, cebus, firestone, equalizer,
# Nearest to had: has, have, was, were, would, oeis, been, having,
# Nearest to state: zombies, government, zimmermann, burgundians, fullerenes, office, suharto, hydrochloride,
# Nearest to there: they, it, he, now, we, often, generally, edomites,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to th: scrupulously, bevan, one, warms, tartarus, jade, graeco, reunification,
# Nearest to zero: five, nine, eight, four, seven, six, three, two,
# Nearest to their: its, his, her, the, our, some, your, them,
# Nearest to which: that, this, what, also, it, who, often, there,
# Average loss at step 42000: 3.394399
# Average loss at step 44000: 3.454757
# Average loss at step 46000: 3.427239
# Average loss at step 48000: 3.398621
# Average loss at step 50000: 3.491777
# Nearest to world: cold, roper, civil, largest, eugenic, practice, compaq, name,
# Nearest to united: headline, caribs, senate, homelands, foldoc, fai, circulation, constitution,
# Nearest to to: will, would, cannot, can, may, might, should, against,
# Nearest to more: less, most, very, phonetically, mostly, nde, straining, alonso,
# Nearest to no: any, floating, there, bonuses, lethe, nothing, little, elizabethan,
# Nearest to would: will, can, may, could, might, should, must, cannot,
# Nearest to in: during, at, within, on, prematurely, of, until, under,
# Nearest to years: days, year, times, caria, decades, months, centuries, nm,
# Nearest to had: has, have, was, were, oeis, been, having, advisers,
# Nearest to state: government, zombies, burgundians, suharto, zimmermann, hydrochloride, fullerenes, prisoners,
# Nearest to there: they, it, he, often, still, we, now, generally,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to th: jade, bevan, scrupulously, four, graeco, tartarus, rd, amadeus,
# Nearest to zero: five, four, eight, seven, six, nine, two, three,
# Nearest to their: its, his, her, the, our, some, your, managua,
# Nearest to which: this, that, also, what, who, it, there, usually,
# Average loss at step 52000: 3.406263
# Average loss at step 54000: 3.264007
# Average loss at step 56000: 3.388651
# Average loss at step 58000: 3.373833
# Average loss at step 60000: 3.418770
# Nearest to world: cold, agonists, roper, largest, tripod, civil, sync, distraught,
# Nearest to united: headline, senate, caribs, foldoc, homelands, constitution, brimstone, personification,
# Nearest to to: opcode, will, cannot, might, disappearing, must, could, would,
# Nearest to more: less, most, very, greater, rather, larger, phonetically, straining,
# Nearest to no: any, little, nothing, unproduced, floating, tipping, there, calcio,
# Nearest to would: will, could, can, may, might, must, should, cannot,
# Nearest to in: during, on, within, prematurely, from, while, at, since,
# Nearest to years: days, year, times, months, decades, centuries, caria, macos,
# Nearest to had: have, has, was, were, oeis, been, having, gave,
# Nearest to state: zimmermann, burgundians, hydrochloride, government, direction, messenger, knot, states,
# Nearest to there: they, it, still, he, we, often, usually, edomites,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to th: bevan, jade, mbit, four, graeco, scrupulously, rd, bc,
# Nearest to zero: five, four, seven, nine, six, eight, three, two,
# Nearest to their: its, his, her, our, the, your, atheromatous, human,
# Nearest to which: that, this, what, who, also, it, but, however,
# Average loss at step 62000: 3.414707
# Average loss at step 64000: 3.371092
# Average loss at step 66000: 3.360552
# Average loss at step 68000: 3.329428
# Average loss at step 70000: 3.281795
# Nearest to world: cold, roper, time, eugenic, tripod, practice, post, largest,
# Nearest to united: headline, senate, caribs, homelands, constitution, burkinabe, personification, foldoc,
# Nearest to to: will, disappearing, opcode, gladiatorial, could, dakota, can, cannot,
# Nearest to more: less, most, very, rather, greater, too, highly, larger,
# Nearest to no: any, little, delusion, landmass, unproduced, tipping, cracks, rheims,
# Nearest to would: could, will, may, can, might, should, must, cannot,
# Nearest to in: within, at, of, prematurely, during, since, on, through,
# Nearest to years: days, times, months, year, decades, centuries, caria, premises,
# Nearest to had: has, have, was, were, having, been, oeis, planetary,
# Nearest to state: government, burgundians, chief, hydrochloride, states, suharto, zimmermann, arrian,
# Nearest to there: they, it, still, often, he, now, we, she,
# Nearest to nine: eight, seven, four, six, five, three, zero, two,
# Nearest to th: jade, six, rd, four, bc, five, bevan, tartarus,
# Nearest to zero: four, five, seven, nine, six, eight, three, two,
# Nearest to their: its, his, her, the, your, our, some, managua,
# Nearest to which: that, this, what, also, who, often, these, usually,
# Average loss at step 72000: 3.364866
# Average loss at step 74000: 3.257943
# Average loss at step 76000: 3.302114
# Average loss at step 78000: 3.250707
# Average loss at step 80000: 3.385502
# Nearest to world: cold, roper, tortoise, eugenic, themes, tet, season, incorporation,
# Nearest to united: senate, headline, personification, burkinabe, caribs, homelands, constitution, circulation,
# Nearest to to: will, cannot, would, opcode, mott, benevento, can, disappearing,
# Nearest to more: less, most, very, greater, rather, too, larger, highly,
# Nearest to no: any, floating, rheims, little, unproduced, tipping, ergot, boyz,
# Nearest to would: will, could, can, might, may, should, must, cannot,
# Nearest to in: within, on, during, under, prematurely, of, since, at,
# Nearest to years: days, year, times, months, decades, centuries, codification, caria,
# Nearest to had: has, have, was, were, having, oeis, according, folktales,
# Nearest to state: government, states, burgundians, prisoners, smelter, customization, relocation, direction,
# Nearest to there: it, they, he, we, she, often, still, now,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to th: bc, jade, rd, ucs, mbit, bevan, tartarus, chandragupta,
# Nearest to zero: five, eight, nine, four, six, seven, three, two,
# Nearest to their: its, his, her, the, your, our, some, managua,
# Nearest to which: that, this, also, what, usually, who, prospective, there,
# Average loss at step 82000: 3.368472
# Average loss at step 84000: 3.357535
# Average loss at step 86000: 3.304491
# Average loss at step 88000: 3.183610
# Average loss at step 90000: 3.344514
# Nearest to world: cold, tet, tripod, agonists, heero, evasive, ingolstadt, battlestar,
# Nearest to united: senate, headline, caribs, prefectures, cancellation, constitution, circulation, burkinabe,
# Nearest to to: will, can, cannot, disappearing, would, benevento, opcode, might,
# Nearest to more: less, most, very, rather, greater, straining, highly, too,
# Nearest to no: any, little, delusion, floating, a, minimal, tipping, rheims,
# Nearest to would: will, could, can, may, might, should, must, cannot,
# Nearest to in: within, with, of, during, from, on, since, at,
# Nearest to years: days, months, times, year, decades, centuries, caria, weeks,
# Nearest to had: has, have, was, were, having, oeis, cores, flywheels,
# Nearest to state: government, burgundians, smelter, states, suharto, customization, prisoners, yoda,
# Nearest to there: it, they, he, we, still, she, now, usually,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to th: bc, rd, jade, six, mbit, ucs, nd, chandragupta,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to their: its, his, her, our, the, some, your, managua,
# Nearest to which: that, this, also, what, but, usually, these, often,
# Average loss at step 92000: 3.365784
# Average loss at step 94000: 3.374605
# Average loss at step 96000: 3.366737
# Average loss at step 98000: 3.374799
# Average loss at step 100000: 3.291333
# Nearest to world: cold, european, sown, tripod, europe, battlestar, roper, compaq,
# Nearest to united: senate, cancellation, prefectures, circulation, headline, constitution, latent, burkinabe,
# Nearest to to: opcode, would, towards, through, should, will, mott, dakota,
# Nearest to more: less, very, most, rather, highly, greater, too, quite,
# Nearest to no: any, little, delusion, only, iblis, unproduced, temair, a,
# Nearest to would: could, will, might, can, should, must, may, cannot,
# Nearest to in: during, within, at, until, under, on, of, from,
# Nearest to years: days, months, decades, times, centuries, year, minutes, weeks,
# Nearest to had: has, have, having, was, were, oeis, eventually, beuve,
# Nearest to state: government, burgundians, states, customization, jesuits, city, prisoners, smelter,
# Nearest to there: they, it, he, we, she, still, shambhala, which,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to th: bc, one, rd, jade, nd, third, mbit, fourth,
# Nearest to zero: five, eight, seven, six, nine, four, two, three,
# Nearest to their: its, his, her, the, our, your, some, my,
# Nearest to which: that, this, however, but, who, what, also, these,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom') # horizontal_aligenment, vertical_alignment
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# Generate batch and label for training a CBOW(Continuous Bag of Words) model

# %%
data_index = 0

def generate_batch_CBOW(batch_size, bag_window):
  global data_index
  batch = np.ndarray(shape=(batch_size, 2 * bag_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  buffer = collections.deque(maxlen=span)

  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    
    for j in range(span):
        if j < bag_window:
            batch[i][j] = buffer[j]
        elif j > bag_window:
            batch[i][j-1] = buffer[j]
        
    labels[i,0] = buffer[bag_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels
    
print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch_CBOW(batch_size=8, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [reverse_dictionary[bi] for row in batch for bi in row])

    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of', 'term', 'abuse', 'of', 'first', 'abuse', 'used', 'first', 'against']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with bag_window = 2:
#     batch: ['anarchism', 'originated', 'a', 'term', 'originated', 'as', 'term', 'of', 'as', 'a', 'of', 'abuse', 'a', 'term', 'abuse', 'first', 'term', 'of', 'first', 'used', 'of', 'abuse', 'used', 'against', 'abuse', 'first', 'against', 'early', 'first', 'used', 'early', 'working']
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# The following two cells are for debugging:

# %% [markdown]
# a = np.arange(12).reshape(3,2,2)
# print(a)
# b = tf.reduce_sum(a,1)

# %% [markdown]
# sess = tf.Session()
# init = tf.global_variables_initializer()
# sess.run(init)
# print(sess.run(b), b.get_shape())

# %% [markdown]
# Train a CBOW(Continuous Bag of Words) model:

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * bag_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset) 
  # embed has the shape (batch_size, 2 * bag_window, embedding_size)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, 
                               inputs=tf.reduce_sum(embed,1), labels=train_labels, 
                               num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_CBOW(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        # note that the highest score is the word itself
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.824672
# Nearest to for: proving, pozna, marxist, overwriting, totality, penh, ci, arin,
# Nearest to nine: cyanide, watchers, intruders, fingered, findable, diversified, limelight, norwegian,
# Nearest to is: henze, allele, slipper, krulak, don, commodity, smpte, sufism,
# Nearest to seven: antiwar, rawlings, cronje, pluralized, mallets, shipowner, boehm, fluorescent,
# Nearest to an: niccol, skulls, cear, cleared, experts, vermont, mice, festive,
# Nearest to many: upside, palms, dolby, ncc, marius, militaries, oppressive, scriptural,
# Nearest to as: relatives, shakyamuni, hwi, eugenia, transsexuals, angle, irb, slanted,
# Nearest to first: swamps, purine, goldeneye, midline, waterfall, shops, smaller, flatly,
# Nearest to no: marilyn, enrolled, squirrel, attacked, chukchi, coast, occupying, krzysztof,
# Nearest to are: nick, poindexter, lincos, hers, ios, buy, alveolar, apollinaire,
# Nearest to system: iain, primary, veracity, mongoloids, equinoxes, surat, columnists, orcus,
# Nearest to however: unifil, manfred, agriculturally, cics, logitech, hbo, deserted, privy,
# Nearest to at: helmet, respect, lull, interviewing, goliath, ramsey, hath, lauren,
# Nearest to had: yankee, fosters, obstruct, ricky, keystrokes, topper, psychometrics, barrie,
# Nearest to zero: bouchard, symmes, pln, sylvester, populist, synchronize, maximally, chromodynamics,
# Nearest to in: saratoga, lonergan, gentoo, shave, agonist, hellenistic, stupidity, dare,
# Average loss at step 2000: 4.089842
# Average loss at step 4000: 3.558939
# Average loss at step 6000: 3.389104
# Average loss at step 8000: 3.242864
# Average loss at step 10000: 3.173748
# Nearest to for: of, analogue, immortal, contradicting, when, with, as, bout,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to is: was, has, are, piracy, be, were, pantomime, postcards,
# Nearest to seven: eight, nine, six, four, five, three, two, zero,
# Nearest to an: the, skulls, affiliated, waved, wic, playback, guitarist, cleared,
# Nearest to many: some, several, other, all, various, metaphors, curve, these,
# Nearest to as: individuality, pediatrics, asparagales, before, for, sample, straps, sidi,
# Nearest to first: second, last, name, oligarchy, procedural, waterfall, chlorophyll, neurologic,
# Nearest to no: marilyn, any, completely, another, chukchi, detention, intermittent, a,
# Nearest to are: were, is, have, quarterbacks, was, zimbabwe, zahn, analyses,
# Nearest to system: veracity, bbl, mongoloids, primary, equinoxes, passover, columnists, jo,
# Nearest to however: deserted, but, unifil, although, mysterious, tuning, embedded, luck,
# Nearest to at: in, on, from, mediums, lull, eapc, africanus, sena,
# Nearest to had: has, have, was, were, ich, keystrokes, academically, halicarnassus,
# Nearest to zero: four, five, eight, six, three, nine, seven, two,
# Nearest to in: on, at, of, from, under, stalemate, with, viridis,
# Average loss at step 12000: 3.202097
# Average loss at step 14000: 3.151004
# Average loss at step 16000: 3.174327
# Average loss at step 18000: 3.120813
# Average loss at step 20000: 2.991472
# Nearest to for: poisonous, interbreed, pozna, analogue, medalist, immortal, toward, after,
# Nearest to nine: eight, six, seven, four, zero, five, three, one,
# Nearest to is: was, has, are, does, became, expressive, be, represents,
# Nearest to seven: six, eight, four, five, nine, zero, three, two,
# Nearest to an: guitarist, portfolio, waved, smoothing, wic, skulls, caricature, gnumeric,
# Nearest to many: some, several, these, various, those, all, most, carey,
# Nearest to as: parton, matured, fading, hl, transhuman, requiem, pediatrics, anniversaries,
# Nearest to first: second, last, next, oligarchy, name, trombonist, podium, riflemen,
# Nearest to no: any, marilyn, another, a, completely, chukchi, persuaded, intermittent,
# Nearest to are: were, is, have, blossoms, include, be, insertions, was,
# Nearest to system: systems, veracity, primary, passover, horses, bbl, mongoloids, lines,
# Nearest to however: but, that, although, mysterious, canto, sprays, dubna, stasi,
# Nearest to at: on, randi, during, in, aide, transferring, belushi, tines,
# Nearest to had: has, have, was, having, were, biopsy, ich, bubi,
# Nearest to zero: seven, six, eight, five, four, nine, three, two,
# Nearest to in: during, on, pakistani, of, at, since, within, bactrian,
# Average loss at step 22000: 3.070959
# Average loss at step 24000: 3.038805
# Average loss at step 26000: 2.999296
# Average loss at step 28000: 3.027249
# Average loss at step 30000: 3.002211
# Nearest to for: including, medalist, javascript, when, penh, contradicting, without, shedding,
# Nearest to nine: seven, eight, six, four, five, zero, three, two,
# Nearest to is: was, has, are, does, became, seems, remains, contains,
# Nearest to seven: nine, six, eight, four, five, three, zero, two,
# Nearest to an: waved, portfolio, caricature, guitarist, blondie, canonised, skulls, latent,
# Nearest to many: some, several, various, these, both, most, other, few,
# Nearest to as: parton, requiem, when, gomorrah, individuality, fading, became, exerts,
# Nearest to first: second, last, next, latter, fourth, oligarchy, previous, third,
# Nearest to no: any, marilyn, blankets, another, completely, simplifying, auspices, only,
# Nearest to are: were, have, is, include, sissy, harlow, outermost, blossoms,
# Nearest to system: systems, veracity, lines, services, horses, passover, primary, bbl,
# Nearest to however: but, although, that, while, though, where, canto, when,
# Nearest to at: during, mediums, in, vieux, computerized, architectural, randi, torch,
# Nearest to had: has, have, was, having, were, norte, became, never,
# Nearest to zero: seven, five, four, nine, eight, six, three, two,
# Nearest to in: within, during, since, on, at, throughout, until, bactrian,
# Average loss at step 32000: 2.822987
# Average loss at step 34000: 2.957047
# Average loss at step 36000: 2.947351
# Average loss at step 38000: 2.940942
# Average loss at step 40000: 2.923934
# Nearest to for: including, after, of, toward, medalist, pozna, anonymously, during,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to is: was, has, are, does, became, seems, be, remains,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to an: portfolio, waved, glacial, blondie, smoothing, lancers, caricature, grandparents,
# Nearest to many: some, several, various, those, most, all, both, few,
# Nearest to as: capitulation, after, dug, individuality, requiem, when, matured, exerts,
# Nearest to first: last, second, third, fourth, best, next, latter, maternal,
# Nearest to no: any, marilyn, little, blankets, lingus, jamaican, sampling, saiyan,
# Nearest to are: were, is, have, sabbatical, be, dolmens, blossoms, include,
# Nearest to system: systems, veracity, unit, lines, guerillas, brockhaus, abnormally, lynyrd,
# Nearest to however: although, that, but, though, where, canto, while, when,
# Nearest to at: during, randi, undesired, uncompetitive, olaf, gnawing, elect, tuttle,
# Nearest to had: has, have, having, was, were, norte, embracing, breuer,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to in: during, within, throughout, since, until, among, from, with,
# Average loss at step 42000: 2.949338
# Average loss at step 44000: 2.954887
# Average loss at step 46000: 2.911106
# Average loss at step 48000: 2.867182
# Average loss at step 50000: 2.841040
# Nearest to for: medalist, including, without, toward, when, pozna, after, if,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to is: was, has, are, contains, seems, be, chemnitz, became,
# Nearest to seven: eight, nine, six, five, four, three, zero, two,
# Nearest to an: portfolio, cleared, smoothing, waved, wic, bettor, guitarist, helios,
# Nearest to many: some, several, various, these, most, all, those, prasad,
# Nearest to as: individuality, like, pediatrics, parton, requiem, capitulation, exerts, notting,
# Nearest to first: last, second, next, latter, fourth, best, third, previous,
# Nearest to no: any, only, marilyn, blankets, another, lingus, chukchi, christened,
# Nearest to are: were, is, have, include, be, while, blossoms, but,
# Nearest to system: systems, veracity, unit, radioisotope, distortion, reymond, thrillers, lines,
# Nearest to however: although, that, but, though, where, canto, while, if,
# Nearest to at: during, in, fpga, under, near, undesired, from, after,
# Nearest to had: has, have, was, having, were, norte, since, ve,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to in: during, within, at, from, throughout, near, of, on,
# Average loss at step 52000: 2.893269
# Average loss at step 54000: 2.868691
# Average loss at step 56000: 2.858561
# Average loss at step 58000: 2.753914
# Average loss at step 60000: 2.828028
# Nearest to for: without, javascript, against, protruding, medalist, mok, poisonous, winthrop,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to is: was, has, are, seems, becomes, contains, does, exists,
# Nearest to seven: eight, five, six, nine, four, three, zero, two,
# Nearest to an: portfolio, waved, helios, gnumeric, skulls, wic, smoothing, diaspora,
# Nearest to many: some, several, various, few, numerous, much, all, those,
# Nearest to as: individuality, requiem, exerts, pediatrics, eyre, when, parton, capitulation,
# Nearest to first: second, last, next, latter, fourth, best, third, previous,
# Nearest to no: any, another, only, little, blankets, saiyan, wrangler, its,
# Nearest to are: were, is, have, include, contain, sissy, although, insertions,
# Nearest to system: systems, veracity, unit, process, radioisotope, method, lines, yn,
# Nearest to however: although, but, that, though, while, nor, where, canto,
# Nearest to at: during, in, under, on, near, esiason, aspartame, netherlands,
# Nearest to had: has, have, was, having, were, norte, breuer, never,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to in: during, within, from, at, on, under, throughout, among,
# Average loss at step 62000: 2.827782
# Average loss at step 64000: 2.770718
# Average loss at step 66000: 2.761279
# Average loss at step 68000: 2.712984
# Average loss at step 70000: 2.787108
# Nearest to for: winthrop, toward, including, medalist, despite, of, embracing, during,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to is: was, remains, contains, seems, has, are, became, refers,
# Nearest to seven: nine, six, five, eight, four, three, zero, two,
# Nearest to an: portfolio, waved, another, the, marbury, wic, diagonal, smoothing,
# Nearest to many: some, several, various, numerous, few, most, those, both,
# Nearest to as: requiem, sopra, armoured, individuality, when, pediatrics, landscaping, mulroney,
# Nearest to first: second, last, next, third, fourth, latter, maternal, previous,
# Nearest to no: any, another, saiyan, auspices, maia, folie, lingus, transformative,
# Nearest to are: were, include, have, is, contain, exist, insertions, be,
# Nearest to system: systems, veracity, precedent, szlachta, method, twinning, process, company,
# Nearest to however: although, but, though, that, while, today, fasttrack, despite,
# Nearest to at: near, on, after, under, in, during, uncompetitive, belushi,
# Nearest to had: has, have, was, having, breuer, were, never, amid,
# Nearest to zero: five, six, eight, seven, four, nine, three, two,
# Nearest to in: during, within, under, throughout, until, of, on, at,
# Average loss at step 72000: 2.797759
# Average loss at step 74000: 2.641883
# Average loss at step 76000: 2.806994
# Average loss at step 78000: 2.819575
# Average loss at step 80000: 2.781732
# Nearest to for: when, without, embracing, while, winthrop, including, after, despite,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to is: was, becomes, has, remains, are, contains, seems, became,
# Nearest to seven: six, five, eight, nine, four, three, zero, two,
# Nearest to an: portfolio, skulls, waved, lancers, smoothing, cleared, canonised, diagonal,
# Nearest to many: some, several, various, numerous, few, most, those, both,
# Nearest to as: individuality, pediatrics, roundly, like, when, kenobi, transhuman, reservists,
# Nearest to first: second, last, next, latter, fourth, third, previous, best,
# Nearest to no: any, little, saiyan, maia, lingus, another, specializing, openoffice,
# Nearest to are: were, is, have, include, blossoms, contain, zahn, exist,
# Nearest to system: systems, veracity, process, technology, lines, guerillas, szlachta, unit,
# Nearest to however: but, although, though, that, despite, etc, where, especially,
# Nearest to at: during, near, in, within, under, emulates, on, fpga,
# Nearest to had: has, have, was, having, were, breuer, never, norte,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to in: within, during, throughout, at, on, near, until, under,
# Average loss at step 82000: 2.667833
# Average loss at step 84000: 2.765812
# Average loss at step 86000: 2.734717
# Average loss at step 88000: 2.753202
# Average loss at step 90000: 2.739390
# Nearest to for: despite, medalist, embracing, interbreed, toward, during, eastwards, winthrop,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to is: was, has, provides, contains, remains, seems, are, becomes,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to an: portfolio, smoothing, lancers, cleared, waved, blondie, geralt, bleak,
# Nearest to many: some, several, numerous, few, various, most, those, both,
# Nearest to as: pediatrics, individuality, lech, exerts, slave, including, repealed, inerrancy,
# Nearest to first: last, second, next, latter, fourth, third, previous, original,
# Nearest to no: any, little, another, become, a, saiyan, bayreuth, lingus,
# Nearest to are: were, include, is, have, contain, including, exist, iiis,
# Nearest to system: systems, process, veracity, lines, twinning, guerillas, yn, method,
# Nearest to however: but, although, though, that, etc, where, heraldic, practically,
# Nearest to at: near, during, in, under, mediums, on, within, glottal,
# Nearest to had: has, have, having, was, breuer, were, amid, saw,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to in: during, throughout, within, on, at, near, including, around,
# Average loss at step 92000: 2.677258
# Average loss at step 94000: 2.728534
# Average loss at step 96000: 2.700866
# Average loss at step 98000: 2.359987
# Average loss at step 100000: 2.400318
# Nearest to for: after, without, embracing, mok, when, during, despite, winthrop,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to is: was, has, became, seems, remains, are, becomes, contains,
# Nearest to seven: six, five, eight, nine, four, three, zero, two,
# Nearest to an: smoothing, portfolio, lancers, democratique, waved, bleak, transcribed, strangle,
# Nearest to many: some, several, numerous, various, few, multiple, such, certain,
# Nearest to as: pediatrics, individuality, exerts, apteryx, after, roundly, stallone, lotta,
# Nearest to first: last, second, next, third, fourth, latter, previous, best,
# Nearest to no: little, any, saiyan, peg, another, maia, gustloff, empirically,
# Nearest to are: were, have, include, is, contain, exist, including, included,
# Nearest to system: systems, lines, veracity, process, method, twinning, yn, network,
# Nearest to however: but, although, though, while, that, since, following, nevertheless,
# Nearest to at: during, near, in, under, on, after, fairway, vieux,
# Nearest to had: has, have, having, was, never, ve, were, argues,
# Nearest to zero: six, four, five, seven, eight, nine, three, two,
# Nearest to in: during, within, at, near, throughout, until, on, unbound,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom') # horizontal_aligenment, vertical_alignment
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
